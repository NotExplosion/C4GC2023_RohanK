# %% [markdown]
# <a href="https://colab.research.google.com/github/NotExplosion/C4GC2023_RohanK/blob/main/Examples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#function to calculate the total mean and standard deviation of an entire time series
def ts_meanstd(ts):
  mean = round(ts.mean(axis=0), 3)
  std = round(ts.std(axis=0), 3)
  print("Mean:", mean, ", Standard Deviation:", std)
  return mean, std

# %%
#importing data; making a copy of the unmodified data for later use

fin_data = pd.read_csv("tute1.csv")
fin_data['Quarter'] = pd.to_datetime(fin_data['Quarter'], format='%Y-%m')
fin_data2 = fin_data.copy()
fin_data2.head()
# Out:
#      Quarter   Sales  AdBudget    GDP
# 0 1981-03-01  1020.2     659.2  251.8
# 1 1981-06-01   889.2     589.0  290.9
# 2 1981-09-01   795.0     512.5  290.8
# 3 1981-12-01  1003.9     614.1  292.4
# 4 1982-03-01  1057.7     647.2  279.1

# %%
#replacing the standard index of the dataframe with a date-time index

fin_data.index = fin_data['Quarter']
del fin_data['Quarter']
fin_data.head()
# Out:
#              Sales  AdBudget    GDP
# Quarter
# 1981-03-01  1020.2     659.2  251.8
# 1981-06-01   889.2     589.0  290.9
# 1981-09-01   795.0     512.5  290.8
# 1981-12-01  1003.9     614.1  292.4
# 1982-03-01  1057.7     647.2  279.1

# %%
#finding the total mean and standard deviation of the data, as well as the rolling mean with a window of size 4

print("Sales Data:")
s_mean, s_std = ts_meanstd(fin_data['Sales'])
print("\nAdvertising Budget Data:")
a_mean, a_std = ts_meanstd(fin_data['AdBudget'])
print("\nGDP Data:")
g_mean, g_std = ts_meanstd(fin_data['GDP'])
fin_data.rolling(4).mean()
# Out:
# Sales Data:
# Mean: 948.737 , Standard Deviation: 98.252
#
# Advertising Budget Data:
# Mean: 591.933 , Standard Deviation: 54.342
#
# GDP Data:
# Mean: 281.183 , Standard Deviation: 14.37
#               Sales  AdBudget      GDP
# Quarter
# 1981-03-01      NaN       NaN      NaN
# 1981-06-01      NaN       NaN      NaN
# 1981-09-01      NaN       NaN      NaN
# 1981-12-01  927.075   593.700  281.475
# 1982-03-01  936.450   590.700  288.300
# ...             ...       ...      ...
# 2004-12-01  993.700   603.350  281.600
# 2005-03-01  999.175   606.950  283.350
# 2005-06-01  998.800   600.100  284.950
# 2005-09-01  988.850   597.475  285.450
# 2005-12-01  982.325   597.300  278.225
#
# [100 rows x 3 columns]

# %%
#rolling standard deviation of the data with a window of size 4
fin_data.rolling(4).std()
# Out:
#                  Sales   AdBudget        GDP
# Quarter
# 1981-03-01         NaN        NaN        NaN
# 1981-06-01         NaN        NaN        NaN
# 1981-09-01         NaN        NaN        NaN
# 1981-12-01  105.597771  61.432727  19.796864
# 1982-03-01  117.603472  57.323468   6.176838
# ...                ...        ...        ...
# 2004-12-01   93.445278  58.321265  12.081667
# 2005-03-01  101.324540  62.358400   8.695784
# 2005-06-01  101.328673  63.306872  10.342953
# 2005-09-01  119.042919  67.840419  10.722717
# 2005-12-01  117.567552  67.712480  18.754088
#
# [100 rows x 3 columns]

# %%
#reading in a data set with multiple time series#
tourism = pd.read_excel("tourism.xls", index_col=None, header=0)

#changing the index format to date-time
tourism['Quarter'] = pd.to_datetime(tourism['Quarter'], format='%Y-%m')
tourism.index = tourism['Quarter']
del tourism['Quarter']
tourism.head()
# Out:
#               Region            State   Purpose       Trips
# Quarter
# 1998-01-01  Adelaide  South Australia  Business  135.077690
# 1998-04-01  Adelaide  South Australia  Business  109.987316
# 1998-07-01  Adelaide  South Australia  Business  166.034687
# 1998-10-01  Adelaide  South Australia  Business  127.160464
# 1999-01-01  Adelaide  South Australia  Business  137.448533

# %%
#grouping the data points by region
regional_tourism = tourism.groupby("Region")

#finding the purpose with the greatest number of trips, based on region
max_tourism = regional_tourism.max()

#finding the combination of region and purpose with the greatest number of trips overall
abs_max = max_tourism.max()
print(abs_max)
max_tourism.head()
# Out:
# State      Western Australia
# Purpose             Visiting
# Trips             985.278401
# dtype: object
#                                          State   Purpose       Trips
# Region
# Adelaide                       South Australia  Visiting  269.535618
# Adelaide Hills                 South Australia  Visiting   81.102109
# Alice Springs               Northern Territory  Visiting   76.541382
# Australia's Coral Coast      Western Australia  Visiting  198.177794
# Australia's Golden Outback   Western Australia  Visiting  173.859915

# %%
#Box-Cox implementation, for later reference
import numpy as np
from scipy import stats
new_tourism = stats.boxcox(fin_data['Sales'])

# %%
#installing the statsforecast module, which allows for simplified forecasting with a variety of methods
# !pip install statsforecast
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.0/100.0 kB 9.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.4/46.4 kB 5.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.6/273.6 kB 28.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.1/169.1 kB 22.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.6/154.6 kB 20.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 279.9/279.9 kB 30.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 92.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.0/137.0 kB 5.0 MB/s eta 0:00:00
# ...

# %%
#Forecasting implementation
from statsforecast import StatsForecast
from statsforecast.models import Naive, SeasonalNaive, RandomWalkWithDrift

#creating the forecasting model, using simple methods (Naive and Seasonal Naive, was unable to implement Random Walk with Drift)
model = StatsForecast(models=[Naive(), SeasonalNaive(season_length=1)], freq='QS', n_jobs=-1)
#print(fin_data[['Sales']])

#for the model to work, the data has to be in a specific format
#'unique_id' is a value that represents which time series a data point belongs to
#in this case, all data is part of the same time series so should have the same 'unique_id'
#'ds' is the date/time column; 'y' is the value being forecasted
fin_data2 = fin_data2.rename({'Quarter':'ds','Sales':'y'}, axis=1)
fin_data2['unique_id'] = 1
fin_data2.head()

#h is the number of data points into the future that the model is forecasting
model.forecast(h=8, df=fin_data2)
# Out:
# /usr/local/lib/python3.10/dist-packages/statsforecast/core.py:21: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
#                   ds       Naive  SeasonalNaive
# unique_id
# 1         2006-01-01  992.599976     992.599976
# 1         2006-04-01  992.599976     992.599976
# 1         2006-07-01  992.599976     992.599976
# 1         2006-10-01  992.599976     992.599976
# 1         2007-01-01  992.599976     992.599976
# 1         2007-04-01  992.599976     992.599976
# 1         2007-07-01  992.599976     992.599976
# 1         2007-10-01  992.599976     992.599976
